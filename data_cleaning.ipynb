# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
path = "/content/drive/MyDrive/titanic/tested.csv"
dset = pd.read_csv(path)

dset.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# ...

# %%
dset.shape
# Out:
# (418, 12)

# %%
dset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
dset.isnull().sum()/dset.shape[0]*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.574163
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.239234
# Cabin          78.229665
# Embarked        0.000000
# dtype: float64

# %%
(dset.isnull().sum().sum()/(dset.shape[0]*dset.shape[1]))*100
# Out:
# np.float64(8.253588516746412)

# %%
dset.isnull().sum().sum()
# Out:
# np.int64(414)

# %%
sns.heatmap(dset.notnull())
plt.show()

# %%
sns.heatmap(dset.isnull())
plt.show()

# %%
#dset.dropna(inplace= True)
#dset.fillna(10)

# %%
dset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
dset.fillna(method="bfill")
dset.head(15)
# Out:
# /tmp/ipykernel_10763/174999565.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dset.fillna(method="bfill")
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# ...

# %%
dset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
dset.select_dtypes(include="float64").columns
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy="mean")
ar = si.fit_transform(dset[['Fare']])
pd.DataFrame(ar,columns=['Fare'])
# Out:
#          Fare
# 0      7.8292
# 1      7.0000
# 2      9.6875
# 3      8.6625
# 4     12.2875
# ..        ...
# 413    8.0500
# 414  108.9000
# 415    7.2500
# 416    8.0500
# 417   22.3583
#
# [418 rows x 1 columns]

# %% [markdown]
# **Duplicate data**

# %%
dset.duplicated().sum()
# Out:
# np.int64(0)

# %%
dset2= pd.read_csv('/content/drive/MyDrive/Mall_Customers.csv')
dset2.duplicated().sum()
# Out:
# np.int64(0)

# %%
data = {'col1': [1, 2, 3, 1, 4, 3],
        'col2': ['A', 'B', 'C', 'A', 'D', 'C']}
df_with_duplicates = pd.DataFrame(data)
print("Original DataFrame:")
display(df_with_duplicates)

print("\nDuplicate rows (marked as True for duplicates):")
display(df_with_duplicates.duplicated())
# Out:
# Original DataFrame:
#    col1 col2
# 0     1    A
# 1     2    B
# 2     3    C
# 3     1    A
# 4     4    D
# 5     3    C
# Duplicate rows (marked as True for duplicates):
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
df_with_duplicates.drop_duplicates(inplace=True)
df_with_duplicates
# Out:
#    col1 col2
# 0     1    A
# 1     2    B
# 2     3    C
# 4     4    D

# %% [markdown]
# **replace data**

# %%
dset3 = pd.read_csv('/content/drive/MyDrive/Outlier_Loan_dataset.csv')
dset3.head()
# Out:
#   User_ID  Loan_ID      City   Age      Job Education Marriage_Status  \
# 0   U2169  L532233    Quetta  39.0    Clerk    Matric         Married
# 1   U2807  L516508   Karachi  33.0   Driver    Matric         Married
# 2   U4536  L471613  Peshawar  41.0  Manager  Bachelor        Divorced
# 3   U9628  L354161    Lahore  50.0   Doctor    Matric         Married
# 4   U8765  L650075   Karachi  32.0  Teacher       PhD         Married
#
#    Account_Balance  Loan_Amount  Credit_Score  Debit_Transactions  \
# 0        269967.77     29744.65        554.61             8955.54
# 1        246231.68    365315.52        606.98            14781.58
# 2        202981.52     26227.40        629.32            15126.12
# 3        167653.16     40761.15        744.38            18308.41
# 4        234911.17     -6808.44        677.83             5431.99
#
#    Loan_Duration_Months Application_Date  Current_Balance
# 0                    45       2024-11-26        139275.96
# ...

# %%
dset3.isnull().sum()
# Out:
# User_ID                 0
# Loan_ID                 0
# City                    0
# Age                     0
# Job                     0
# Education               0
# Marriage_Status         0
# Account_Balance         0
# Loan_Amount             0
# Credit_Score            0
# Debit_Transactions      0
# Loan_Duration_Months    0
# Application_Date        0
# Current_Balance         0
# dtype: int64

# %%
dset3.fillna("noage",inplace=True)

# %%
dset3['Age'].replace('noage',"0",inplace=True)
# Out:
# /tmp/ipykernel_10763/3489787289.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dset3['Age'].replace('noage',"0",inplace=True)

# %%
dset3['Age'] = dset3['Age'].astype(np.int64)

# %%
dset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   User_ID               1000 non-null   object
#  1   Loan_ID               1000 non-null   object
#  2   City                  1000 non-null   object
#  3   Age                   1000 non-null   int64
#  4   Job                   1000 non-null   object
#  5   Education             1000 non-null   object
#  6   Marriage_Status       1000 non-null   object
#  7   Account_Balance       1000 non-null   float64
#  8   Loan_Amount           1000 non-null   object
#  9   Credit_Score          1000 non-null   float64
#  10  Debit_Transactions    1000 non-null   float64
#  11  Loan_Duration_Months  1000 non-null   int64
#  12  Application_Date      1000 non-null   object
#  13  Current_Balance       1000 non-null   float64
# dtypes: float64(4), int64(2), object(8)
# ...
